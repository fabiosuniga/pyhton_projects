# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiosuniga/pyhton_projects/blob/main/rpg_bola_de_fogo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

enemy = [
    {'id' : 1, 'nome' : 'goblin jovem', 'hp' : 7},
    {'id' : 2, 'nome' : 'esqueleto', 'hp' : 20},
    {'id' : 3, 'nome' : 'cão infernal', 'hp' : 33},
    {'id' : 4, 'nome' : 'assassino', 'hp' : 60},
    {'id' : 5, 'nome' : 'civil', 'hp' : 3},
]

print(f"A Horda possui {len(enemy)} Inimigos\n\nInimigos restantes:")

for enemies in enemy:
    print(f"{enemies['nome']}: HP restante: {enemies['hp']}")

bola_de_fogo = 0
for dano in range(8):
  bola_de_fogo += random.randint(1, 6)

print(f"\nA bola de fogo deu {bola_de_fogo} de dano!")

for enemies in enemy[:]:
    enemies['hp'] -= bola_de_fogo
    if enemies['hp'] <= 0:
        enemy.remove(enemies)

print(f"\n\nA Horda possui {len(enemy)} Inimigos\n\nInimigos restantes:")

for enemies in enemy:
    print(f"{enemies['nome']}: HP restante: {enemies['hp']}")
# Out:
# A Horda possui 5 Inimigos
#
# Inimigos restantes:
# goblin jovem: HP restante: 7
# esqueleto: HP restante: 20
# cão infernal: HP restante: 33
# assassino: HP restante: 60
# civil: HP restante: 3
#
# A bola de fogo deu 24 de dano!
#
#
# A Horda possui 2 Inimigos
#
# Inimigos restantes:
# cão infernal: HP restante: 9
# assassino: HP restante: 36
